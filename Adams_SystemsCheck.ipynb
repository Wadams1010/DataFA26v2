# %% [markdown]
# # This is a Header!

# %% [markdown]
# ## This is a Sub-Header!

# %% [markdown]
# **This text is bold.** *This text is italic.*

# %% [markdown]
# ![testimage](TestImageJNotebook.jpg)

# %% [markdown]
# 1. I hope that I will learn more about how Python specifically works in this class.
# 2. I also hope to get more used to the process of writing code in general.
# 3. Let's have a great semester!
